# %% [markdown]
# World Port Index Data Migration(Capstone Project 2)

# %%
 pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
import zipfile
import os

# Specify the path to the zip file and the extraction directory
zip_file_path = r"C:\Users\admin\Downloads\PUB150.zip"
extraction_path = r"C:\Users\admin\Downloads\PUB150"

# Make sure the extraction directory exists or create it
os.makedirs(extraction_path, exist_ok=True)

# Extract files from the zip archive
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print("Extraction complete.")
# Out:
# Extraction complete.

# %%
import pyodbc
[x for x in pyodbc.drivers() if x.startswith('Microsoft Access Driver')]
# Out:
# []

# %%
def connect_to_database(database_path):
    # Open a connection to the Access database using the provided database_path
    conn = pyodbc.connect(fr'DRIVER={{Microsoft Access Driver (*.mdb, *.accdb)}};DBQ={database_path};')
    return conn

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
pyodbc.dataSources()
# Out:
# {'MS Access Database': 'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Excel Files': 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'dBASE Files': 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)'}

# %%
def get_accessbase_conn():
    return pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\Users\admin\Downloads\PUB150\WPI.mdb')
conn = get_accessbase_conn()
cursor = conn.cursor()
# Get the list of table names
table_names = [table.table_name for table in cursor.tables(tableType="TABLE")]
# Print the table names
for name in table_names:
    print(name)
# Out:
# ~TMPCLP62091
# Country Codes
# Country Codes Old
# Depth Code LUT
# Drydock/Marine Railway Code LUT
# Harbor Size LUT
# Harbor Type LUT
# Maximum Size Vessel LUT
# Repairs Code LUT
# Shelter Afforded LUT
# Wpi Data
# WPI Import
# WPI Region

# %%
def query_accessdb_table(query, conn):
    table_result = pd.read_sql(query, conn)
    return table_result
query = """
SELECT * FROM "Wpi Data"

"""
table_result = query_accessdb_table(query, conn)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8760\348665687.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   table_result = pd.read_sql(query, conn)

# %%
table_result
# Out:
#       World_port_index_number  Region_index  Main_port_name Wpi_country_code  \
# 0                          70            60        KEFLAVIK               IS
# 1                          75            60      STRAUMSVIK               IS
# 2                          80            60   HAFNARFJORDUR               IS
# 3                          90            60   SKERJAFJORDUR               IS
# 4                         100            60       REYKJAVIK               IS
# ...                       ...           ...             ...              ...
# 3625                     8270          6585  FREDERICKSBURG               US
# 3626                     8280          6585         NORFOLK               US
# 3627                     8290          6585      PORTSMOUTH               US
# 3628                     8300          6585    NEWPORT NEWS               US
# 3629                     8318          6585         WARWICK               US
#
# ...

# %%
import os

db_password = os.environ.get("DB_PASSWORD")

# %%
# Load the dataset into the database
# Database credentials
db_username = 'postgres'
db_password = os.environ.get("DB_PASSWORD")
db_host = 'localhost'
db_port ='5432'
db_name = 'world_port_index'

# %%
#  Establish a connection using SQLAlchemy engine
connection = create_engine(f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
import pyodbc

# %%
def connect_to_database(database_path):
    # Open a connection to the Access database using the provided database_path
    conn = pyodbc.connect(fr'DRIVER={{Microsoft Access Driver (*.mdb, *.accdb)}};DBQ={database_path};')
    return conn

# %%
database_path = r'C:\Users\admin\Downloads\PUB150\WPI.mdb'

# %%
connection = connect_to_database(database_path)

# %%
def get_table_names(connection):
    # Get the table names using a list comprehension and the tables() method
    cursor = connection.cursor()
    table_names = [table.table_name for table in cursor.tables(tableType="TABLE")]
    return table_names

# %%
# Call the function to retrieve table names
table_names = get_table_names(connection)

# %%
# Close the connection
#connection.close()

# Iterate through table names and print each name
for name in table_names:
    print(name)
# Out:
# ~TMPCLP62091
# Country Codes
# Country Codes Old
# Depth Code LUT
# Drydock/Marine Railway Code LUT
# Harbor Size LUT
# Harbor Type LUT
# Maximum Size Vessel LUT
# Repairs Code LUT
# Shelter Afforded LUT
# Wpi Data
# WPI Import
# WPI Region

# %%
#assigning a SQL query string to the variable named query, its a select statement that retrieves all column from a table named "Wpi Data"
query = '''    
SELECT * FROM "Wpi Data"
'''

# %%
import pandas as pd

# %%
# Fetch table data as a pandas DataFrame, it fetches the data from the database using the read_sql function. 
table_data = pd.read_sql(query, connection)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8760\2557169208.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   table_data = pd.read_sql(query, connection)

# %%
# Print the first few rows of the DataFrame
print(table_data.head())
# Out:
#    World_port_index_number  Region_index Main_port_name Wpi_country_code  \
# 0                       70            60       KEFLAVIK               IS
# 1                       75            60     STRAUMSVIK               IS
# 2                       80            60  HAFNARFJORDUR               IS
# 3                       90            60  SKERJAFJORDUR               IS
# 4                      100            60      REYKJAVIK               IS
#
#    Latitude_degrees  Latitude_minutes Latitude_hemisphere  Longitude_degrees  \
# 0                64                 0                   N                 22
# 1                64                 3                   N                 22
# 2                64                 4                   N                 21
# 3                64                 9                   N                 22
# 4                64                 9                   N                 21
#
# ...

# %%
table_data
# Out:
#       World_port_index_number  Region_index  Main_port_name Wpi_country_code  \
# 0                          70            60        KEFLAVIK               IS
# 1                          75            60      STRAUMSVIK               IS
# 2                          80            60   HAFNARFJORDUR               IS
# 3                          90            60   SKERJAFJORDUR               IS
# 4                         100            60       REYKJAVIK               IS
# ...                       ...           ...             ...              ...
# 3625                     8270          6585  FREDERICKSBURG               US
# 3626                     8280          6585         NORFOLK               US
# 3627                     8290          6585      PORTSMOUTH               US
# 3628                     8300          6585    NEWPORT NEWS               US
# 3629                     8318          6585         WARWICK               US
#
# ...

# %%
table_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3630 entries, 0 to 3629
# Data columns (total 76 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   World_port_index_number     3630 non-null   int64
#  1   Region_index                3630 non-null   int64
#  2   Main_port_name              3630 non-null   object
#  3   Wpi_country_code            3630 non-null   object
#  4   Latitude_degrees            3630 non-null   int64
#  5   Latitude_minutes            3630 non-null   int64
#  6   Latitude_hemisphere         3629 non-null   object
#  7   Longitude_degrees           3630 non-null   int64
#  8   Longitude_minutes           3630 non-null   int64
#  9   Longitude_hemisphere        3629 non-null   object
#  10  Publication                 3494 non-null   object
#  11  Chart                       2744 non-null   object
#  12  Harbor_size_code            3624 non-null   object
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://postgres:Faithful_0102@localhost:5432/world_port_index")
connection = engine.connect()
table_data.to_sql ("Wpi Data", con=engine, if_exists='replace', index=False)
# Out:
# 190

# %%
import os

db_password = os.environ.get("DB_PASSWORD")

# %%
#Question 1
#Establish the five nearest ports to Singapore's JURONG ISLAND port (country =
#'SG', port_name = 'JURONG ISLAND'). The output should encompass 'port_name'
#and 'distance_in_meters' exclusively.


# This connection will be used to run queries on the PostgreSQL database
import os
import psycopg2
import pandas as pd

def nearest_ports_to_jurong_island():
    # Connect to the PostgreSQL database
    conn = psycopg2.connect(
        user='postgres',
        password=os.environ.get("DB_PASSWORD"),
        host='localhost',
        port='5432',
        database='world_port_index'
    )
    
    # Run SQL query to find the 5 nearest ports to JURONG ISLAND
    sql_query = """
    SELECT
        "Main_port_name",
        (
            6371000 *
            acos(
                cos(radians(1)) * cos(radians("Latitude_degrees")) * cos(radians("Longitude_degrees") - radians(103.98765)) +
                sin(radians(1)) * sin(radians("Latitude_degrees"))
            )
        ) AS distance_in_meters
    FROM
        "World_Port_Index"
    WHERE
        "Wpi_country_code" = 'SG'
        AND "Main_port_name" != 'JURONG ISLAND'
    ORDER BY
        distance_in_meters
    LIMIT 5;
    """

# %%
get_ipython().run_line_magic('load_ext', 'sql')
